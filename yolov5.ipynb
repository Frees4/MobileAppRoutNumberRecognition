# %%
from google.colab import drive
import os
import torch
import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from IPython.display import Image  # for displaying images

# %%
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.11.0+cu113 CPU

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %%
# !pip install torch==1.10.1+cu111 torchvision==0.11.2+cu111 torchaudio==0.10.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████▌                   | 834.1 MB 1.3 MB/s eta 0:16:29tcmalloc: large alloc 1147494400 bytes == 0x3a7b6000 @  0x7ff97787f615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |███████████████▉                | 1055.7 MB 1.3 MB/s eta 0:13:32tcmalloc: large alloc 1434370048 bytes == 0x7ee0c000 @  0x7ff97787f615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolov5-master
# Out:
# /content/drive/MyDrive/yolov5-master

# %%
# !python -m torch.distributed.launch --nproc_per_node 1 train.py --img 320 --batch 32 --epochs 100 --data dataset.yaml --cfg ./models/custom_yolov5s.yaml --weights yolov5s.pt --name yolov5s --cache
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node 1 train.py --img 416 --batch 32 --epochs 100 --data dataset.yaml --cfg ./models/custom_yolov5s.yaml --weights yolov5s.pt --name yolov5s416 --cache
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node 1 train.py --img 416 --batch 32 --epochs 100 --data dataset.yaml --cfg ./models/custom_yolov5n.yaml --weights yolov5n.pt --name yolov5n --cache
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# ...

# %%
# GPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5n2/weights/best.pt --img 416 --device 0 --name busn416
# Out:
# detect: weights=['runs/train/yolov5n2/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=busn416, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 416x416 2 objects, Done. (0.017s)
# Speed: 0.6ms pre-process, 16.6ms inference, 9.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/busn4166

# %%
# CPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5n2/weights/best.pt --img 416 --name busn416cpu
# Out:
# detect: weights=['runs/train/yolov5n2/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=busn416cpu, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 416x416 2 objects, Done. (0.126s)
# Speed: 2.6ms pre-process, 126.3ms inference, 9.6ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/busn416cpu

# %%
# GPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5s416/weights/best.pt --img 416 --device 0 --name buss416
# Out:
# detect: weights=['runs/train/yolov5s416/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=buss416, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 416x416 1 object, Done. (0.028s)
# Speed: 0.4ms pre-process, 28.5ms inference, 2.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/buss416

# %%
# CPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5s416/weights/best.pt --img 416 --name buss416cpu
# Out:
# detect: weights=['runs/train/yolov5s416/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=buss416cpu, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 416x416 1 object, Done. (0.187s)
# Speed: 1.1ms pre-process, 187.0ms inference, 1.1ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/buss416cpu

# %%
# GPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5s2/weights/best.pt --img 320 --device 0 --name buss320
# Out:
# detect: weights=['runs/train/yolov5s2/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=buss320, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 320x320 2 objects, Done. (0.027s)
# Speed: 0.3ms pre-process, 26.6ms inference, 1.8ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/buss320

# %%
# CPU
# !python detect.py --source bus128.jpg --weights runs/train/yolov5s2/weights/best.pt --img 320 --name buss320cpu
# Out:
# detect: weights=['runs/train/yolov5s2/weights/best.pt'], source=bus128.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=buss320cpu, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/yolov5-master/bus128.jpg: 320x320 2 objects, Done. (0.136s)
# Speed: 0.8ms pre-process, 136.2ms inference, 0.9ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/buss320cpu

# %%
# !python val.py --img 416 --device 0 --data dataset.yaml --task 'test' --weights runs/train/yolov5n2/weights/best.pt --name yolov5nrun
# Out:
# val: data=dataset.yaml, weights=['runs/train/yolov5n2/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=test, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=yolov5nrun, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients
# test: Scanning 'dataset/labels/test' images and labels...27 found, 0 missing, 12 empty, 0 corrupted: 100% 27/27 [00:34<00:00,  1.26s/it]
# test: New cache created: dataset/labels/test.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.08s/it]
#                  all         27         21      0.666      0.571       0.57      0.302
# ...

# %%
# !python val.py --img 416 --device 0 --data dataset.yaml --task 'test' --weights runs/train/yolov5s416/weights/best.pt --name yolov5s416run
# Out:
# val: data=dataset.yaml, weights=['runs/train/yolov5s416/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=test, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=yolov5s416run, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
# test: Scanning 'dataset/labels/test.cache' images and labels... 27 found, 0 missing, 12 empty, 0 corrupted: 100% 27/27 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.15s/it]
#                  all         27         21      0.769      0.476      0.562       0.27
# Speed: 0.2ms pre-process, 11.8ms inference, 4.3ms NMS per image at shape (32, 3, 416, 416)
# Results saved to runs/val/yolov5s416run

# %%
# !python val.py --img 320 --device 0 --data dataset.yaml --task 'test' --weights runs/train/yolov5s2/weights/best.pt --name yolov5s2run
# Out:
# val: data=dataset.yaml, weights=['runs/train/yolov5s2/weights/best.pt'], batch_size=32, imgsz=320, conf_thres=0.001, iou_thres=0.6, task=test, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=yolov5s2run, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2022-1-13 torch 1.10.1+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# test: Scanning 'dataset/labels/test.cache' images and labels... 27 found, 0 missing, 12 empty, 0 corrupted: 100% 27/27 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.69s/it]
#                  all         27         21      0.687      0.522      0.409      0.156
# Speed: 0.1ms pre-process, 10.6ms inference, 3.0ms NMS per image at shape (32, 3, 320, 320)
# Results saved to runs/val/yolov5s2run

# %%
# !python export.py --weights runs/train/yolov5s416/weights/best.pt --include tflite engine --img 416
# Out:
# ...
# export: data=data/coco128.yaml, weights=['runs/train/yolov5s416/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite', 'engine']
# YOLOv5 🚀 2022-1-13 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
#
# PyTorch: starting from runs/train/yolov5s416/weights/best.pt (14.3 MB)
# requirements: tensorrt not found and is required by YOLOv5, attempting auto-update...
# ...
#   Created wheel for tensorrt: filename=tensorrt-0.0.1-py3-none-any.whl size=1154 sha256=b9f69da83d42c5b2839168db67764e6e7100646103c33e45c51e7a3f445af5f1
#   Stored in directory: /root/.cache/pip/wheels/8a/78/48/f3d96950a3a858998e81705789cdfd98298a900c264baf2b5f
# Successfully built tensorrt
# ...
#
# ...

# %%
# !python export.py --weights runs/train/yolov5n2/weights/best.pt --include tflite engine --img 416
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/yolov5n2/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite', 'engine']
# YOLOv5 🚀 2022-1-13 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients
#
# PyTorch: starting from runs/train/yolov5n2/weights/best.pt (3.8 MB)
#
# TensorRT: export failure: No module named 'tensorrt'
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.0...
#
#                  from  n    params  module                                  arguments
# 2022-04-15 17:28:57.454721: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !python export.py --weights runs/train/yolov5s2/weights/best.pt --include tflite engine
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/yolov5s2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite', 'engine']
# YOLOv5 🚀 2022-1-13 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
#
# PyTorch: starting from runs/train/yolov5s2/weights/best.pt (14.8 MB)
#
# TensorRT: export failure: No module named 'tensorrt'
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.0...
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
# ...
